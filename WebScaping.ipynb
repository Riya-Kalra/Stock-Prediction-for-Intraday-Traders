# %%
import requests
from bs4 import BeautifulSoup
stock=["RELIANCE"]#, "HDFC", "TCS", "HDFCBANK", "LT", "INFY", "KOTAKBANK", "ITC", "SBIN", "ICICIBANK"]
for stockcode in stock:
  print(stockcode)
  stock_url  = 'https://www.nseindia.com/live_market/dynaContent/live_watch/get_quote/GetQuote.jsp?symbol='+str(stockcode)
  print(stock_url)
  headers = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.117 Safari/537.36'}
  response = requests.get(stock_url, headers=headers)
  response
  soup = BeautifulSoup(response.text, 'html.parser')
  data_array = soup.find(id='responseDiv').getText().strip().split(":")
  type (data_array)
  print(data_array)
  for item in data_array:
      if 'lastPrice' in item:
          index = data_array.index(item)+1
          print("LatestPrice")
          latestPrice=data_array[index].split('"')[1]
          print(latestPrice)
      elif 'open' in item:
          index = data_array.index(item)+1
          print("Open")
          openPrice=data_array[index].split('"')[1]
          print(openPrice)
      elif 'dayLow' in item:
          index = data_array.index(item)+1
          print("Low")
          Low=data_array[index].split('"')[1]
          print(Low)
      elif 'dayHigh' in item:
          index = data_array.index(item)+1
          print("High")
          High=data_array[index].split('"')[1]
          print(High)
      elif 'averagePrice' in item:
          index = data_array.index(item)+1
          print("vwap")
          vwap=data_array[index].split('"')[1]
          print(vwap)
# Out:
# RELIANCE
# https://www.nseindia.com/live_market/dynaContent/live_watch/get_quote/GetQuote.jsp?symbol=RELIANCE
# ['{"tradedDate"', '"28APR2022","data"', '[{"pricebandupper"', '"3,056.15","symbol"', '"RELIANCE","applicableMargin"', '"15.40","bcEndDate"', '"-","totalSellQuantity"', '"13,331","adhocMargin"', '"-","companyName"', '"Reliance Industries Limited","marketType"', '"N","exDate"', '"11-JUN-21","bcStartDate"', '"-","css_status_desc"', '"Listed","dayHigh"', '"2,851.00","basePrice"', '"2,778.35","securityVar"', '"11.90","pricebandlower"', '"2,500.55","sellQuantity5"', '"-","sellQuantity4"', '"-","sellQuantity3"', '"-","cm_adj_high_dt"', '"28-APR-22","sellQuantity2"', '"-","dayLow"', '"2,786.10","sellQuantity1"', '"13,331","quantityTraded"', '"98,49,226","pChange"', '"1.14","totalTradedValue"', '"3,33,810.17","deliveryToTradedQuantity"', '"60.44","totalBuyQuantity"', '"-","averagePrice"', '"2,823.90","indexVar"', '"-","cm_ffm"', '"9,58,554.88","purpose"', '"DIVIDEND - RS 7 PER SHARE","buyPrice2"', '"-","secDate"', '"28-Apr-2022 15', '00', '00","buyPrice1"', '"-","high52"', '"2,851.00","previousClose"', '"2,778.35","ndEndDate"', '"-","low52"', '"1,906.00","buyPrice4"', '"-","buyPrice3"', '"-","recordDate"', '"14-JUN-21","deliveryQuantity"', '"59,52,894","buyPrice5"', '"-","priceBand"', '"No Band","extremeLossMargin"', '"3.50","cm_adj_low_dt"', '"14-MAY-21","varMargin"', '"11.90","sellPrice1"', '"2,819.85","sellPrice2"', '"-","totalTradedVolume"', '"1,18,20,892","sellPrice3"', '"-","sellPrice4"', '"-","sellPrice5"', '"-","change"', '"31.65","surv_indicator"', '"-","ndStartDate"', '"-","buyQuantity4"', '"-","isExDateFlag"', 'false,"buyQuantity3"', '"-","buyQuantity2"', '"-","buyQuantity1"', '"-","series"', '"EQ","faceValue"', '"10.00","buyQuantity5"', '"-","closePrice"', '"0.00","open"', '"2,809.95","isinCode"', '"INE002A01018","lastPrice"', '"2,810.00"}],"optLink"', '"\\/marketinfo\\/sym_map\\/symbolMapping.jsp?symbol=RELIANCE&instrument=-&date=-&segmentLink=17&symbolCount=2","otherSeries"', '["EQ"],"futLink"', '"\\/live_market\\/dynaContent\\/live_watch\\/get_quote\\/GetQuoteFO.jsp?underlying=RELIANCE&instrument=FUTSTK&expiry=28APR2022&type=-&strike=-","lastUpdateTime"', '"28-APR-2022 16', '00', '12"}']
# High
# 2,851.00
# Low
# 2,786.10
# vwap
# 2,823.90
# Open
# 2,809.95
# LatestPrice
# 2,810.00
